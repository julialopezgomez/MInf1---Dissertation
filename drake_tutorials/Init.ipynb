# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# cd /work
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# bash: line 2: cd: /work: No such file or directory
# sed: 1: "./requirements.txt": invalid command code .
# WARNING: The directory '/Users/julialg2002/Library/Caches/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you should use sudo's -H flag.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ipywidgets==7.7.0 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from -r ./requirements.txt (line 1)) (7.7.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (6.27.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (5.14.0)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (5.9.2)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (8.18.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (3.0.9)
# Requirement already satisfied: appnope in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (0.1.3)
# Requirement already satisfied: comm>=0.1.1 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (5.5.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (0.1.6)
# Requirement already satisfied: nest-asyncio in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (1.5.8)
# Requirement already satisfied: packaging in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (23.2)
# Requirement already satisfied: psutil in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (5.9.6)
# Requirement already satisfied: pyzmq>=20 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (25.1.1)
# Requirement already satisfied: tornado>=6.1 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (6.4)
# Requirement already satisfied: decorator in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from ipython>=4.0.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from ipython>=4.0.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from ipython>=4.0.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (3.0.41)
# Requirement already satisfied: pygments>=2.4.0 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from ipython>=4.0.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (2.17.2)
# Requirement already satisfied: stack-data in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from ipython>=4.0.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (0.6.3)
# Requirement already satisfied: typing-extensions in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from ipython>=4.0.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (4.8.0)
# Requirement already satisfied: exceptiongroup in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from ipython>=4.0.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from ipython>=4.0.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: fastjsonschema in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from nbformat>=4.2.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (2.19.0)
# Requirement already satisfied: jsonschema>=2.6 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from nbformat>=4.2.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (4.20.0)
# Requirement already satisfied: notebook>=4.4.1 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (7.0.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (2023.11.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (0.31.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (0.13.1)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (6.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (4.0.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (2.11.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (2.25.2)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (4.0.9)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (0.2.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (0.2.12)
# Requirement already satisfied: executing>=1.2.0 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=4.0.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=4.0.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=4.0.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from asttokens>=2.1.0->stack-data->ipython>=4.0.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: zipp>=0.5 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=4.8.3->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (3.17.0)
# Requirement already satisfied: anyio>=3.1.0 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (4.1.0)
# Requirement already satisfied: argon2-cffi in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (23.1.0)
# Requirement already satisfied: jinja2 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (3.1.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (0.9.0)
# Requirement already satisfied: jupyter-server-terminals in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (7.11.0)
# Requirement already satisfied: overrides in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (7.4.0)
# Requirement already satisfied: prometheus-client in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (0.19.0)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (0.18.0)
# Requirement already satisfied: websocket-client in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (1.6.4)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from jupyterlab<5,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from jupyterlab<5,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: tomli in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from jupyterlab<5,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: babel>=2.10 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (2.13.1)
# Requirement already satisfied: json5>=0.9.0 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (0.9.14)
# Requirement already satisfied: requests>=2.31 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (2.31.0)
# Requirement already satisfied: idna>=2.8 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (3.6)
# Requirement already satisfied: sniffio>=1.1 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from jinja2->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (2.1.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: rfc3339-validator in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (6.1.0)
# Requirement already satisfied: defusedxml in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (0.9.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (1.5.0)
# Requirement already satisfied: tinycss2 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (1.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (2023.11.17)
# Requirement already satisfied: argon2-cffi-bindings in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (21.2.0)
# Requirement already satisfied: webencodings in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (0.5.1)
# Requirement already satisfied: fqdn in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (1.5.1)
# Requirement already satisfied: isoduration in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (2.4)
# Requirement already satisfied: uri-template in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (2.5)
# Requirement already satisfied: pycparser in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from isoduration->jsonschema>=2.6->nbformat>=4.2.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /Users/julialg2002/Library/Python/3.9/lib/python/site-packages (from arrow>=0.15.0->isoduration->jsonschema>=2.6->nbformat>=4.2.0->ipywidgets==7.7.0->-r ./requirements.txt (line 1)) (2.8.19.14)
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip

# %%
# %%bash
# /opt/drake/share/drake/setup/deepnote/install_nginx
# /opt/drake/share/drake/setup/deepnote/install_xvfb
# Out:
# + with_update=1
# + '[' '' '!=' '' ']'
# + [[ 501 -eq 0 ]]
# + command -v conda
# + echo 'NOTE: Drake is not tested regularly with Anaconda, so you may experience compatibility hiccups; when asking for help, be sure to mention that Conda is involved.'
# NOTE: Drake is not tested regularly with Anaconda, so you may experience compatibility hiccups; when asking for help, be sure to mention that Conda is involved.
# + command -v brew
# + [[ -z '' ]]
# + export HOMEBREW_NO_AUTO_UPDATE=1
# + HOMEBREW_NO_AUTO_UPDATE=1
# + export HOMEBREW_NO_INSTALL_CLEANUP=1
# + HOMEBREW_NO_INSTALL_CLEANUP=1
# + binary_distribution_called_update=0
# + [[ 1 -eq 1 ]]
# + brew update
# Already up-to-date.
# + binary_distribution_called_update=1
# + brew bundle --file=/Users/julialg2002/drake/share/drake/setup/Brewfile --no-lock
# Using robotlocomotion/director
# Installing adoptopenjdk
# ==> Caveats
# Temurin is the official successor to this software:
#
#   brew install --cask temurin
#
# adoptopenjdk has been officially discontinued upstream.
# It may stop working correctly (or at all) in recent versions of macOS.
#
# ==> Downloading https://github.com/AdoptOpenJDK/openjdk16-binaries/releases/download/jdk-16.0.1%2B9/OpenJDK16U-jdk_x64_mac_hotspot_16.0.1_9.pkg
# Already downloaded: /Users/julialg2002/Library/Caches/Homebrew/downloads/0a31dff56b954586711fe23ece23226e61a0771acdab722ed289f7cdfea153d9--OpenJDK16U-jdk_x64_mac_hotspot_16.0.1_9.pkg
# ==> Installing Cask adoptopenjdk
# ==> Running installer for adoptopenjdk with sudo; the password may be necessary.
# sudo: a terminal is required to read the password; either use the -S option to read from standard input or configure an askpass helper
# sudo: a password is required
# Error: Failure while executing; `/usr/bin/sudo -u root -E LOGNAME=julialg2002 USER=julialg2002 USERNAME=julialg2002 -- /usr/sbin/installer -pkg /usr/local/Caskroom/adoptopenjdk/16.0.1,9/OpenJDK16U-jdk_x64_mac_hotspot_16.0.1_9.pkg -target /` exited with 1. Here's the output:
# sudo: a terminal is required to read the password; either use the -S option to read from standard input or configure an askpass helper
# sudo: a password is required
# ==> Purging files for version 16.0.1,9 of Cask adoptopenjdk
# Installing adoptopenjdk has failed!
# Using cmake
# Using eigen
# Using gcc
# Using fmt
# Using glib
# Using graphviz
# Using ipopt
# Using jpeg
# Using numpy
# Error: Could not symlink bin/f2py
# Target /usr/local/bin/f2py
# already exists. You may want to remove it:
#   rm '/usr/local/bin/f2py'
#
# To force the link and overwrite all conflicting files:
#   brew link --overwrite numpy
#
# To list all files that would be deleted:
#   brew link --overwrite --dry-run numpy
# Linking /usr/local/Cellar/numpy/1.26.2...
# Using openblas
# Using pkg-config
# Using python@3.11
# Error: Could not symlink bin/2to3
# Target /usr/local/bin/2to3
# already exists. You may want to remove it:
#   rm '/usr/local/bin/2to3'
#
# To force the link and overwrite all conflicting files:
#   brew link --overwrite python@3.11
#
# To list all files that would be deleted:
#   brew link --overwrite --dry-run python@3.11
# Linking /usr/local/Cellar/python@3.11/3.11.6_1...
# Using spdlog
# Using tinyxml
# Using xz
# Using yaml-cpp
# Using zeromq
# Homebrew Bundle failed! 1 Brewfile dependency failed to install.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /Users/julialg2002/Desktop/UoEYear4/Dissertation/robotic-arm-dissertation/tutorials/drake_tutorials/Init.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/Users/julialg2002/Desktop/UoEYear4/Dissertation/robotic-arm-dissertation/tutorials/drake_tutorials/Init.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> get_ipython().run_cell_magic('bash', '', '/Users/julialg2002/drake/share/drake/setup/install_prereqs\n')
#
# File ~/Library/Python/3.9/lib/python/site-packages/IPython/core/interactiveshell.py:2517, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2515 with self.builtin_trap:
#    2516     args = (magic_arg_s, cell)
# -> 2517     result = fn(*args, **kwargs)
#    2519 # The code below prevents the output from being displayed
#    2520 # when using magics with decorator @output_can_be_silenced
#    2521 # when the last Python token in the expression is a ';'.
#    2522 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/Library/Python/3.9/lib/python/site-packages/IPython/core/magics/script.py:154, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     152 else:
#     153     line = script
# --> 154 return self.shebang(line, cell)
#
# File ~/Library/Python/3.9/lib/python/site-packages/IPython/core/magics/script.py:314, in ScriptMagics.shebang(self, line, cell)
#     309 if args.raise_error and p.returncode != 0:
#     310     # If we get here and p.returncode is still None, we must have
#     311     # killed it but not yet seen its return code. We don't wait for it,
#     312     # in case it's stuck in uninterruptible sleep. -9 = SIGKILL
#     313     rc = p.returncode or -9
# --> 314     raise CalledProcessError(rc, cell)
#
# CalledProcessError: Command 'b'/Users/julialg2002/drake/share/drake/setup/install_prereqs\n'' returned non-zero exit status 1.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=2b4fc509-aef2-417d-a40d-6071dfed9199' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
